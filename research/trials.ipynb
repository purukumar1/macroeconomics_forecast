# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("WEOOct2024.csv")
df.head()
# Out:
#   WEO Country Code  ISO WEO Subject Code      Country  \
# 0              512  AFG           NGDP_R  Afghanistan
# 1              512  AFG        NGDP_RPCH  Afghanistan
# 2              512  AFG             NGDP  Afghanistan
# 3              512  AFG            NGDPD  Afghanistan
# 4              512  AFG           PPPGDP  Afghanistan
#
#                         Subject Descriptor  \
# 0  Gross domestic product, constant prices
# 1  Gross domestic product, constant prices
# 2   Gross domestic product, current prices
# 3   Gross domestic product, current prices
# 4   Gross domestic product, current prices
#
#                                        Subject Notes  \
# 0  Expressed in billions of national currency uni...
# 1  Annual percentages of constant price GDP are y...
# 2  Expressed in billions of national currency uni...
# 3  Values are based upon GDP in national currency...
# 4  These data form the basis for the country weig...
#
#                                             Units     Scale  \
# 0                               National currency  Billions
# 1                                  Percent change     Units
# 2                               National currency  Billions
# 3                                    U.S. dollars  Billions
# 4  Purchasing power parity; international dollars  Billions
#
#                        Country/Series-specific Notes 1980  ...      2021  \
# 0  Source: National Statistics Office Latest actu...    0  ...  1,101.45
# 1  See notes for:  Gross domestic product, consta...    0  ...   -14.542
# 2  Source: National Statistics Office Latest actu...    0  ...  1,251.17
# 3  See notes for:  Gross domestic product, curren...    0  ...    14.278
# 4  See notes for:  Gross domestic product, curren...    0  ...    85.768
#
#        2022      2023 2024 2025 2026 2027 2028 2029 Estimates Start After
# 0  1,032.71  1,060.71    0    0    0    0    0    0                2024.0
# 1     -6.24     2.711    0    0    0    0    0    0                2024.0
# 2  1,283.44  1,357.28    0    0    0    0    0    0                2024.0
# 3    14.501    17.329    0    0    0    0    0    0                2024.0
# 4    86.149    91.668    0    0    0    0    0    0                2024.0
#
# [5 rows x 60 columns]

# %%
for year in range(1980, 2026):
    year_str = str(year)
    df[year_str] = pd.to_numeric(df[year_str].str.replace(',', ''), errors='coerce').fillna(0)

# %% [markdown]
# ### Top 10 countries that grew "Gross domestic product per capita (PPP)" the most over the last decade

# %%
gdp_data = df[df["WEO Subject Code"] == "NGDPRPPPPC"]
gdp_data
# Out:
#      WEO Country Code  ISO WEO Subject Code             Country  \
# 7                 512  AFG       NGDPRPPPPC         Afghanistan
# 51                914  ALB       NGDPRPPPPC             Albania
# 95                612  DZA       NGDPRPPPPC             Algeria
# 139               171  AND       NGDPRPPPPC             Andorra
# 183               614  AGO       NGDPRPPPPC              Angola
# ...               ...  ...              ...                 ...
# 8411              582  VNM       NGDPRPPPPC             Vietnam
# 8455              487  WBG       NGDPRPPPPC  West Bank and Gaza
# 8499              474  YEM       NGDPRPPPPC               Yemen
# 8543              754  ZMB       NGDPRPPPPC              Zambia
# 8587              698  ZWE       NGDPRPPPPC            Zimbabwe
#
#                                      Subject Descriptor  \
# 7     Gross domestic product per capita, constant pr...
# 51    Gross domestic product per capita, constant pr...
# 95    Gross domestic product per capita, constant pr...
# 139   Gross domestic product per capita, constant pr...
# 183   Gross domestic product per capita, constant pr...
# ...                                                 ...
# 8411  Gross domestic product per capita, constant pr...
# 8455  Gross domestic product per capita, constant pr...
# 8499  Gross domestic product per capita, constant pr...
# 8543  Gross domestic product per capita, constant pr...
# 8587  Gross domestic product per capita, constant pr...
#
#                                           Subject Notes  \
# 7     GDP is expressed in constant international dol...
# 51    GDP is expressed in constant international dol...
# 95    GDP is expressed in constant international dol...
# 139   GDP is expressed in constant international dol...
# 183   GDP is expressed in constant international dol...
# ...                                                 ...
# 8411  GDP is expressed in constant international dol...
# 8455  GDP is expressed in constant international dol...
# 8499  GDP is expressed in constant international dol...
# 8543  GDP is expressed in constant international dol...
# 8587  GDP is expressed in constant international dol...
#
#                                                   Units  Scale  \
# 7     Purchasing power parity; 2017 international do...  Units
# 51    Purchasing power parity; 2017 international do...  Units
# 95    Purchasing power parity; 2017 international do...  Units
# 139   Purchasing power parity; 2017 international do...  Units
# 183   Purchasing power parity; 2017 international do...  Units
# ...                                                 ...    ...
# 8411  Purchasing power parity; 2017 international do...  Units
# 8455  Purchasing power parity; 2017 international do...  Units
# 8499  Purchasing power parity; 2017 international do...  Units
# 8543  Purchasing power parity; 2017 international do...  Units
# 8587  Purchasing power parity; 2017 international do...  Units
#
#                           Country/Series-specific Notes      1980  ...  \
# 7     See notes for:  Gross domestic product, consta...      0.00  ...
# 51    See notes for:  Gross domestic product, consta...   6042.03  ...
# 95    See notes for:  Gross domestic product, consta...  12113.96  ...
# 139   See notes for:  Gross domestic product, consta...      0.00  ...
# 183   See notes for:  Gross domestic product, consta...   4989.29  ...
# ...                                                 ...       ...  ...
# 8411  See notes for:  Gross domestic product, consta...   1653.90  ...
# 8455  See notes for:  Gross domestic product, consta...      0.00  ...
# 8499  See notes for:  Gross domestic product, consta...      0.00  ...
# 8543  See notes for:  Gross domestic product, consta...   3375.84  ...
# 8587  See notes for:  Gross domestic product, consta...      0.00  ...
#
#           2021      2022      2023      2024      2025       2026       2027  \
# 7      2138.87   1954.58   1958.60      0.00      0.00          0          0
# 51    16262.60  17260.96  18037.01  18811.44  19645.29  20,538.62  21,248.78
# 95    14559.50  14848.17  15227.46  15592.13  15853.62  16,046.92  16,194.34
# 139   58458.65  62438.30  60725.54  60378.94  60152.74  59,868.40  59,585.41
# 183    8869.64   8931.34   8716.48   8624.90   8565.65   8,546.65   8,532.20
# ...        ...       ...       ...       ...       ...        ...        ...
# 8411  12101.36  12958.72  13498.90  14250.11  14994.67  15,776.41  16,578.64
# 8455   5333.29   5418.90   5011.10      0.00      0.00          0          0
# 8499   1903.27   1892.32   1813.72   1756.52   1743.70   1,825.82   1,903.51
# 8543   3526.51   3610.67   3703.39   3687.44   3827.83   3,946.68   4,059.33
# 8587   4182.61   4350.43   4473.77   4462.14   4631.79   4,740.32   4,806.63
#
#            2028       2029  Estimates Start After
# 7             0          0                 2023.0
# 51    21,985.74  22,748.26                 2021.0
# 95    16,342.22  16,490.97                 2019.0
# 139   59,303.75  59,023.42                 2023.0
# 183    8,520.77   8,512.27                 2021.0
# ...         ...        ...                    ...
# 8411  17,409.14  18,246.66                 2023.0
# 8455          0          0                 2023.0
# 8499   1,976.10   2,042.51                 2022.0
# 8543   4,158.24   4,252.99                 2022.0
# 8587   4,869.87   4,933.78                 2017.0
#
# [196 rows x 60 columns]

# %%
current_time = gdp_data['2024']
ten_years_ago = gdp_data['2014']

gdp_data['Growth'] = current_time - ten_years_ago
# Out:
# C:\Users\puruk\AppData\Local\Temp\ipykernel_12932\61775682.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_data['Growth'] = current_time - ten_years_ago

# %%
top10 = gdp_data.sort_values(by='Growth', ascending=False).head(10)
top10
# Out:
#      WEO Country Code  ISO WEO Subject Code                   Country  \
# 3131              336  GUY       NGDPRPPPPC                    Guyana
# 3571              178  IRL       NGDPRPPPPC                   Ireland
# 5111              943  MNE       NGDPRPPPPC                Montenegro
# 6739              576  SGP       NGDPRPPPPC                 Singapore
# 4759              181  MLT       NGDPRPPPPC                     Malta
# 7487              528  TWN       NGDPRPPPPC  Taiwan Province of China
# 1943              423  CYP       NGDPRPPPPC                    Cyprus
# 1899              960  HRV       NGDPRPPPPC                   Croatia
# 6079              964  POL       NGDPRPPPPC                    Poland
# 6255              968  ROU       NGDPRPPPPC                   Romania
#
#                                      Subject Descriptor  \
# 3131  Gross domestic product per capita, constant pr...
# 3571  Gross domestic product per capita, constant pr...
# 5111  Gross domestic product per capita, constant pr...
# 6739  Gross domestic product per capita, constant pr...
# 4759  Gross domestic product per capita, constant pr...
# 7487  Gross domestic product per capita, constant pr...
# 1943  Gross domestic product per capita, constant pr...
# 1899  Gross domestic product per capita, constant pr...
# 6079  Gross domestic product per capita, constant pr...
# 6255  Gross domestic product per capita, constant pr...
#
#                                           Subject Notes  \
# 3131  GDP is expressed in constant international dol...
# 3571  GDP is expressed in constant international dol...
# 5111  GDP is expressed in constant international dol...
# 6739  GDP is expressed in constant international dol...
# 4759  GDP is expressed in constant international dol...
# 7487  GDP is expressed in constant international dol...
# 1943  GDP is expressed in constant international dol...
# 1899  GDP is expressed in constant international dol...
# 6079  GDP is expressed in constant international dol...
# 6255  GDP is expressed in constant international dol...
#
#                                                   Units  Scale  \
# 3131  Purchasing power parity; 2017 international do...  Units
# 3571  Purchasing power parity; 2017 international do...  Units
# 5111  Purchasing power parity; 2017 international do...  Units
# 6739  Purchasing power parity; 2017 international do...  Units
# 4759  Purchasing power parity; 2017 international do...  Units
# 7487  Purchasing power parity; 2017 international do...  Units
# 1943  Purchasing power parity; 2017 international do...  Units
# 1899  Purchasing power parity; 2017 international do...  Units
# 6079  Purchasing power parity; 2017 international do...  Units
# 6255  Purchasing power parity; 2017 international do...  Units
#
#                           Country/Series-specific Notes      1980  ...  \
# 3131  See notes for:  Gross domestic product, consta...   6613.24  ...
# 3571  See notes for:  Gross domestic product, consta...  22562.83  ...
# 5111  See notes for:  Gross domestic product, consta...      0.00  ...
# 6739  See notes for:  Gross domestic product, consta...  27203.64  ...
# 4759  See notes for:  Gross domestic product, consta...  17870.92  ...
# 7487  See notes for:  Gross domestic product, consta...   9329.86  ...
# 1943  See notes for:  Gross domestic product, consta...  17271.16  ...
# 1899  See notes for:  Gross domestic product, consta...      0.00  ...
# 6079  See notes for:  Gross domestic product, consta...  14214.51  ...
# 6255  See notes for:  Gross domestic product, consta...  16502.66  ...
#
#            2022       2023       2024       2025        2026        2027  \
# 3131   36420.37   48281.08   69226.92   78982.73   92,497.01  111,590.51
# 3571  123168.57  114422.94  112420.41  113697.22  115,103.62  116,462.24
# 5111       0.00   27037.39   28035.12   29057.89   29,914.67   30,796.71
# 6739  132468.93  127543.56  130403.79  132764.03  135,194.69  137,516.24
# 4759   60332.77   62334.64   64189.03   65532.63   66,625.73   67,729.54
# 7487   66158.62   67044.34   69547.51   71403.78   73,252.77   75,107.59
# 1943   50676.09   51023.63   52675.06   53835.54   54,994.03   56,189.74
# 1899   40088.87   41451.91   42953.86   44272.82   45,559.91   46,839.12
# 6079   43737.20   43969.55   45433.48   47102.25   48,792.49   50,388.31
# 6255   39695.68   40522.80   41539.38   43166.24   45,043.45   47,014.81
#
#             2028        2029  Estimates Start After    Growth
# 3131  126,241.79  140,867.17                 2022.0  57911.60
# 3571  117,839.56  119,355.11                 2023.0  47226.26
# 5111   31,704.76   32,639.58                 2023.0  28035.12
# 6739  139,832.06  142,405.26                 2023.0  23799.30
# 4759   68,898.02   70,143.35                 2023.0  19563.38
# 7487   76,989.60   78,643.15                 2023.0  18200.72
# 1943   57,427.99   58,728.56                 2023.0  15791.15
# 1899   48,136.63   49,470.08                 2023.0  14796.40
# 6079   51,993.09   53,586.96                 2023.0  14766.98
# 6255   48,956.39   51,014.79                 2023.0  13260.95
#
# [10 rows x 61 columns]

# %%
', '.join(top10['Country'].to_list())
# Out:
# 'Guyana, Ireland, Montenegro, Singapore, Malta, Taiwan Province of China, Cyprus, Croatia, Poland, Romania'

# %%
gdp_data[gdp_data['Country'] == 'Montenegro']
# Out:
#      WEO Country Code  ISO WEO Subject Code     Country  \
# 5111              943  MNE       NGDPRPPPPC  Montenegro
#
#                                      Subject Descriptor  \
# 5111  Gross domestic product per capita, constant pr...
#
#                                           Subject Notes  \
# 5111  GDP is expressed in constant international dol...
#
#                                                   Units  Scale  \
# 5111  Purchasing power parity; 2017 international do...  Units
#
#                           Country/Series-specific Notes  1980  ...  2022  \
# 5111  See notes for:  Gross domestic product, consta...   0.0  ...   0.0
#
#           2023      2024      2025       2026       2027       2028  \
# 5111  27037.39  28035.12  29057.89  29,914.67  30,796.71  31,704.76
#
#            2029  Estimates Start After    Growth
# 5111  32,639.58                 2023.0  28035.12
#
# [1 rows x 61 columns]
